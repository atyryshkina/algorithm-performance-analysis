# %%
import argparse
import scipy
from sklearn.externals import joblib
import math

import pandas as pd

from sklearn import preprocessing
from sklearn_pandas import gen_features
from sklearn_pandas import DataFrameMapper

from sklearn import ensemble
import sklearn
import numpy as np
from matplotlib import pyplot as plt
from preprocessing import ChooseFeatureColumns
from preprocessing import MyMapper
import ast
import os
import skgarden

import mysql.connector
from tabulate import tabulate

cnx = mysql.connector.connect(user='root', password='root',
                              host='localhost',
                              database='datadump')
cursor = cnx.cursor()

class TrainModel(object):

    def __init__(self, filename):

        try:
            self.df=pd.read_csv("data/csv_dump/%s.csv"%filename)
        except FileNotFoundError as e:
            print("dont have this file yet")
            return
        df2=pd.read_csv("failed_jobs/walltime_csv/%s.csv"%filename)
        # df3=pd.read_csv("failed_jobs/memory_csv/%s.csv"%filename)
        self.df["result"], df2["result"]="ok", "walltime error"

        self.df.index=self.df["id"]
        df2.index=df2["id"]
        self.df=pd.concat([self.df,df2])
        self.df=self.df.sort_values("id")
        del self.df["id"]
        self.df=self.df.reset_index()

        self.df=self.remove_bad_columns(self.df)
        self.df=self.remove_bad_columns(self.df)

        num_errors=df2.shape[0]
        df_features, df_labels = self.df, self.df.pop("result")
        num_instances=len(df_labels)

        original_num_of_cols=df_features.shape[1]
        ################################################
        ################################################
        # prepare the data for the RandomForestRegressor
        print("setting up...")
        chooser = ChooseFeatureColumns()
        scaler = MyMapper()
        # regr = sklearn.ensemble.RandomForestRegressor(n_estimators=100, max_depth=12)
        self.regr=sklearn.ensemble.RandomForestClassifier(n_estimators=100, max_depth=12)

        self.pipe = sklearn.pipeline.Pipeline([
            ('chooser',chooser),
            ('scaler', scaler),
        ])
        # ################################################
        test_size = 0.2
        test_start=len(df_labels)-int(len(df_labels)*test_size)
 
        split_randomly=False
        time_split=num_instances>10
        if split_randomly and time_split:
            tr_features, ev_features, tr_labels, ev_labels = sklearn.model_selection.train_test_split(df_features, df_labels, test_size=test_size)
            print("splitting randomly")
        elif time_split:
            tr_features, tr_labels, ev_features, ev_labels = df_features[:test_start], df_labels[:test_start], df_features[test_start:], df_labels[test_start:]
            print("splitting non-randomly")
        if time_split and ((len(list(self.pipe.fit_transform(tr_features)))) != (len(list(self.pipe.transform(ev_features))))):
            print("!! pipe transformation broken")
            time_split=False
        # ################################################

        df_features=self.pipe.fit_transform(df_features)
        print("%r ----> %r" %(original_num_of_cols,df_features.shape[1]))
        if float(df_features.shape[1])/float(original_num_of_cols)>10:
            print("GREATER THAN 10")

        if time_split:
            tr_features=self.pipe.fit_transform(tr_features)
            ev_features=self.pipe.transform(ev_features)
             
        self.table="walltime_classify"

        accuracy=self.analysis(filename, df_features, df_labels, df_features, df_labels, timesplit=False)
        print("whole accuracy: %r" % accuracy)
        if time_split:
            accuracy2 = self.analysis(filename, tr_features, tr_labels, ev_features, ev_labels, timesplit=True)
            print("time accuracy: %r" % accuracy2)
            
            metrics={"toolid": filename, "num_instances":num_instances,
                    "accuracy": accuracy, "accuracy_time":accuracy2, "num_errors":num_errors}
            print(tabulate(sorted([(k,v) for k,v in metrics.items()])))
            command = '''INSERT INTO walltime_classify (toolid, num_instances, accuracy, accuracy_time_split, num_walltime_errors) 
                            
                            VALUES (%(toolid)s, %(num_instances)s, %(accuracy)s,%(accuracy_time)s,%(num_errors)s)
                            
                            ON DUPLICATE KEY UPDATE num_instances=%(num_instances)s, accuracy=%(accuracy)s, 
                            accuracy_time_split=%(accuracy_time)s, num_walltime_errors=%(num_errors)s;
                            '''
        else:
            metrics={"toolid": filename, "num_instances":num_instances, "accuracy": accuracy, "num_errors":num_errors}
            command = '''INSERT INTO walltime_classify (toolid, num_instances, accuracy, num_walltime_errors) 
                            
                            VALUES (%(toolid)s, %(num_instances)s, %(accuracy)s, %(num_errors)s)
                            
                            ON DUPLICATE KEY UPDATE num_instances=%(num_instances)s, accuracy=%(accuracy)s, num_walltime_errors=%(num_errors)s;
                            '''
        # print(tabulate(sorted([(k,v) for k,v in metrics.items()])))
        cursor.execute(command, metrics)
        cnx.commit()
        
        print("done")
        
    def remove_bad_columns(self, df):
        parameters = [i for i in list(df) if (i.startswith("parameters.") and not i.startswith("parameters.__job_r"))]
        filetypes=[i for i in list(df) if (i.endswith("_filetype") and not i.startswith("parameters.__job_r"))]
        files=[i[:-9] for i in filetypes]
        bad_parameters=["parameters.__workflow_invocation_uuid__","parameters.chromInfo"]
        for parameter in parameters:
            series=df[parameter].dropna()
            if all(type(item)==str and item.startswith('"') for item in series): 
                try:
                    df[parameter]=df[parameter].str[1:-1].astype(float)
                except:
                    pass
            if len(df[parameter].unique())>=0.5*df.shape[0]:
                bad_parameters.append(parameter)
            if df[parameter].dtype == object and len(df[parameter].unique())>=10*df.shape[1]:
                bad_parameters.append(parameter)
            if all(type(item)==str and item.startswith("[") and item.endswith("]") for item in series):#  and item.startswith("[{'src'")
                if all(type(ast.literal_eval(item))==list for item in series):
                    bad_parameters.append(parameter)
        for file in files:
            bad_parameters.append("parameters."+file)
            bad_parameters.append("parameters."+file+".values")
            bad_parameters.append("parameters."+file+"|__identifier__")
        for param in set(bad_parameters):
            try:
                parameters.remove(param)
            except:
                pass
        hardware=['destination_id',
         'galaxy_slots',
         'handler',
         'job_runner_name',
         'memtotal',
         'processor_count',
         'result']
        keep=parameters+filetypes+files+hardware
        columns=list(df)
        for column in columns:
            if not column in keep:
                del df[column]
        return df
        
    def analysis(self, filename, tr_features, tr_labels, ev_features, ev_labels, timesplit=False):
        self.regr.fit(tr_features,tr_labels)
        ev_pred = self.regr.predict(ev_features)
        accuracy=sklearn.metrics.accuracy_score(ev_labels,ev_pred) 
        return float(accuracy)
        
    def get_accuracy(self, cq):
        correct = 0.
        i=0
        for k, r in cq.iterrows():
            if r["labels"] < (r["pred"]+r["std"]) and r["labels"] > (r["pred"]-r["std"]):
                correct+=1.
            i+=1
        

        return (correct/cq.shape[0])

    def plot(self, cq, filename, timesplit=False):
        plot=True
        plot_w_error=True
        if plot:
            plt.figure(figsize=(10,10))
            plt.scatter(cq["labels"],cq["pred"])
            plt.xlabel("Real Runtime")
            plt.ylabel("Predicted Runtime")
            plt.title("Mean predictions")
            if timesplit:
                plt.savefig("plots_dump/timesplit/%s.png"%filename)
                print("saved a plot to plots_dump/timesplit/%s.png"%filename)
            else:
                plt.savefig("plots_dump/%s.png"%filename)
                print("saved a plot to plots_dump/%s.png"%filename)
            plt.close()
        if plot_w_error:
            plt.figure(figsize=(10,10))
            plt.scatter(cq["labels"],cq["pred"])
            plt.errorbar(cq["labels"],cq["pred"], yerr=[cq["std"],cq["std"]], fmt='o')
            plt.xlabel("Real Runtime")
            plt.ylabel("Predicted Runtime")
            plt.title("Mean predictions")
            if timesplit:
                plt.savefig("plots_w_error_dump/timesplit/%s.png"%filename)
                print("saved a plot to plots_w_error_dump/timesplit/%s.png"%filename)
            else:
                plt.savefig("plots_w_error_dump/%s.png"%filename)
                print("saved a plot to plots_w_error_dump/%s.png"%filename)
            
            plt.close()



def getfiles(dirpath):
    a = [s for s in os.listdir(dirpath)
         if os.path.isfile(os.path.join(dirpath, s))]
    a.sort(key=lambda s: os.path.getmtime(os.path.join(dirpath, s)), reverse=True)
    return a


toolids=getfiles("failed_jobs/walltime_csv")
toolids=[i[:-4] for i in toolids]
toolids=["dummy"]
print(toolids)
# toolids=["iuc_vsearch_vsearch_masking_1.9.7.0"]

for i in range(len(toolids)):
    print(i, toolids[i])
    TrainModel(toolids[i])

cursor.close()
cnx.close()

# %%
import argparse
import scipy
from sklearn.externals import joblib
import math

import pandas as pd

from sklearn import preprocessing
from sklearn_pandas import gen_features
from sklearn_pandas import DataFrameMapper

from sklearn import ensemble
import sklearn
import numpy as np
from matplotlib import pyplot as plt
from preprocessing import ChooseFeatureColumns
from preprocessing import MyMapper
import ast
import os
import skgarden

import mysql.connector
from tabulate import tabulate

# %%
def remove_bad_columns(df):
        parameters = [i for i in list(df) if (i.startswith("parameters.") and not i.startswith("parameters.__job_r"))]
        filetypes=[i for i in list(df) if (i.endswith("_filetype") and not i.startswith("parameters.__job_r"))]
        files=[i[:-9] for i in filetypes]
        bad_parameters=["parameters.__workflow_invocation_uuid__","parameters.chromInfo"]
        for parameter in parameters:
            series=df[parameter].dropna()
            if all(type(item)==str and item.startswith('"') for item in series): 
                try:
                    df[parameter]=df[parameter].str[1:-1].astype(float)
                except:
                    pass
            if len(df[parameter].unique())>=0.5*df.shape[0]:
                bad_parameters.append(parameter)
            if df[parameter].dtype == object and len(df[parameter].unique())>=10*df.shape[1]:
                bad_parameters.append(parameter)
            if all(type(item)==str and item.startswith("[") and item.endswith("]") for item in series):#  and item.startswith("[{'src'")
                if all(type(ast.literal_eval(item))==list for item in series):
                    bad_parameters.append(parameter)
        for file in files:
            bad_parameters.append("parameters."+file)
            bad_parameters.append("parameters."+file+".values")
            bad_parameters.append("parameters."+file+"|__identifier__")
        for param in set(bad_parameters):
            try:
                parameters.remove(param)
            except:
                pass
        hardware=[
#             'destination_id',
#          'galaxy_slots',
#          'handler',
#          'job_runner_name',
#          'memtotal',
#          'processor_count',
         'result']
        keep=parameters+filetypes+files+hardware
        columns=list(df)
        for column in columns:
            if not column in keep:
                del df[column]
        return df

# %%
filename="devteam_clustalw_clustalw_0.1"
df=pd.read_csv("../data/csv_dump/%s.csv"%filename)
df2=pd.read_csv("walltime_csv/%s.csv"%filename)
# Out:
# /Users/atyrysh/development/ber1/.venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
number_of_errors=df2.shape[0]
if number_of_errors< df.shape[0]:
    df=df.sample(number_of_errors)

# %%
df2
# Out:
#      chromInfo chromInfo_filetype                 create_time destination_id  \
# 0          NaN                NaN  2015-03-14 15:41:58.335428   rodeo_normal
# 1          NaN                NaN  2015-05-04 19:39:59.598199   slurm_normal
# 2          NaN                NaN  2015-03-20 16:32:56.394793   rodeo_normal
# 3          NaN                NaN  2015-03-31 03:27:12.385371   rodeo_normal
# 4          NaN                NaN  2015-03-31 10:59:10.622449   rodeo_normal
# 5          NaN                NaN  2015-04-02 05:26:39.008336   slurm_normal
# 6          NaN                NaN  2015-04-08 09:30:04.370373   slurm_normal
# 7          NaN                NaN  2015-05-06 14:39:06.746495   slurm_normal
# 8          NaN                NaN  2015-04-15 07:31:00.119212   slurm_normal
# 9          NaN                NaN  2015-04-17 12:56:35.493576   slurm_normal
# 10         NaN                NaN  2016-01-26 14:45:59.404698   slurm_normal
# 11         NaN                NaN  2015-04-22 10:35:58.567593   slurm_normal
# 12         NaN                NaN  2015-04-22 10:35:24.817997   slurm_normal
# 13         NaN                NaN  2015-04-22 10:33:30.782551   slurm_normal
# 14         NaN                NaN  2015-04-22 10:36:18.937459   slurm_normal
# 15         NaN                NaN  2015-04-21 23:02:26.165756   slurm_normal
# 16         NaN                NaN  2015-04-29 03:30:40.625079   slurm_normal
# 17         NaN                NaN  2015-04-29 07:15:12.621857   slurm_normal
# 18    133234.0                len  2015-05-03 02:28:36.063212   slurm_normal
# 19         NaN                NaN  2015-05-14 12:16:11.638769   slurm_normal
# 20         NaN                NaN  2015-06-23 12:57:50.608932   slurm_normal
# 21         NaN                NaN  2015-04-29 03:31:26.399020   slurm_normal
# 22         NaN                NaN  2015-04-30 08:26:55.591365   slurm_normal
# 23         NaN                NaN  2015-05-19 09:56:18.651546   slurm_normal
# 24         NaN                NaN  2015-06-24 04:33:54.378644   slurm_normal
# 25         NaN                NaN  2015-05-26 02:42:34.922218   slurm_normal
# 26         NaN                NaN  2015-05-29 10:58:06.982877   slurm_normal
# 27         NaN                NaN  2015-05-27 08:16:14.672609   slurm_normal
# 28         NaN                NaN  2015-05-27 22:37:14.493374   slurm_normal
# 29         NaN                NaN  2015-05-29 16:35:46.568476   slurm_normal
# ..         ...                ...                         ...            ...
# 422        NaN                NaN  2017-11-21 15:00:40.383962   slurm_normal
# 423        NaN                NaN  2017-11-21 15:09:30.519336   slurm_normal
# 424        NaN                NaN  2017-11-20 16:01:36.855804   slurm_normal
# 425        NaN                NaN  2017-11-21 15:09:31.245159   slurm_normal
# 426        NaN                NaN  2017-11-21 15:00:40.759416   slurm_normal
# 427        NaN                NaN  2017-11-21 15:00:41.361852   slurm_normal
# 428        NaN                NaN  2017-11-21 15:09:40.475538   slurm_normal
# 429        NaN                NaN  2017-11-21 15:09:31.700372   slurm_normal
# 430        NaN                NaN  2017-11-26 02:54:34.082604   slurm_normal
# 431        NaN                NaN  2018-01-12 15:07:32.007815   slurm_normal
# 432        NaN                NaN  2017-11-21 15:09:31.485388   slurm_normal
# 433        NaN                NaN  2017-11-21 15:09:30.126876   slurm_normal
# 434        NaN                NaN  2017-11-21 15:09:35.164669   slurm_normal
# 435        NaN                NaN  2017-12-01 08:26:33.734082   slurm_normal
# 436        NaN                NaN  2017-11-21 15:09:38.513979   slurm_normal
# 437        NaN                NaN  2017-11-21 15:09:31.920968   slurm_normal
# 438        NaN                NaN  2017-12-06 03:17:20.231424   slurm_normal
# 439        NaN                NaN  2017-11-21 15:09:33.794567   slurm_normal
# 440        NaN                NaN  2017-11-21 15:09:30.931470   slurm_normal
# 441        NaN                NaN  2017-12-08 01:42:31.837664   slurm_normal
# 442        NaN                NaN  2018-01-16 13:48:33.272623   slurm_normal
# 443        NaN                NaN  2017-11-21 15:09:34.973244   slurm_normal
# 444        NaN                NaN  2017-11-21 15:09:36.023093   slurm_normal
# 445        NaN                NaN  2017-11-21 15:09:34.573628   slurm_normal
# 446        NaN                NaN  2018-03-07 12:06:47.771972   slurm_normal
# 447        NaN                NaN  2018-01-23 09:46:35.579667   slurm_normal
# 448        NaN                NaN  2018-03-06 18:42:05.895076   slurm_normal
# 449        NaN                NaN  2018-01-30 21:48:30.760269   slurm_normal
# 450        NaN                NaN  2018-03-01 13:43:15.630185   slurm_normal
# 451        NaN                NaN  2018-02-27 19:44:42.647332   slurm_normal
#
#      exit_code           handler  history_id        id  imported  \
# 0          NaN  main_w1_handler0     2011729   8948522     False
# 1          NaN  main_w2_handler1     2257279   9390355     False
# 2          NaN  main_w2_handler0     2175991   8997301     False
# 3          NaN  main_w2_handler1     2254688   9097900     False
# 4          NaN  main_w2_handler1     2138873   9100215     False
# 5          NaN  main_w1_handler1     2257683   9121744     False
# 6          NaN  main_w2_handler1     2263378   9169469     False
# 7          NaN  main_w2_handler0     2295689   9411063     False
# 8          NaN  main_w1_handler0     2270591   9234723     False
# 9          NaN  main_w2_handler1     2249772   9256461     False
# 10         NaN  main_w1_handler1     2578576  11607506     False
# 11         NaN  main_w2_handler0     2260904   9298396     False
# 12         NaN  main_w1_handler0     2260904   9298394     False
# 13         NaN  main_w2_handler1     2260904   9298385     False
# 14         NaN  main_w2_handler0     2260904   9298397     False
# 15         NaN  main_w2_handler0     2227334   9294078     False
# 16         NaN  main_w2_handler0     2286929   9357495     False
# 17         NaN  main_w2_handler0     1375182   9358098     False
# 18         NaN  main_w2_handler1     2251814   9381445     False
# 19         NaN  main_w2_handler0     2280879   9470694     False
# 20         NaN  main_w2_handler1     2352943   9715208     False
# 21         NaN  main_w2_handler0     2253032   9357497     False
# 22         NaN  main_w1_handler1     2288635   9366817     False
# 23         NaN  main_w1_handler1     2280879   9494171     False
# 24         NaN  main_w1_handler2     1044371   9721908     False
# 25         NaN  main_w1_handler0     1943920   9532105     False
# 26         NaN  main_w1_handler1     2322502   9561392     False
# 27         NaN  main_w2_handler0     2318692   9542583     False
# 28         NaN  main_w2_handler1     2321508   9548082     False
# 29         NaN  main_w1_handler0     2323217   9562998     False
# ..         ...               ...         ...       ...       ...
# 422        NaN  main_w4_handler0     3322362  17536916     False
# 423        NaN  main_w4_handler0     3289187  17537391     False
# 424        NaN  main_w4_handler1     2005348  17521529     False
# 425        NaN  main_w3_handler0     3289187  17537394     False
# 426        NaN  main_w4_handler1     3322362  17536917     False
# 427        NaN  main_w3_handler1     3322362  17536918     False
# 428        NaN  main_w3_handler1     3289187  17537431     False
# 429        NaN  main_w4_handler0     3289187  17537396     False
# 430        NaN  main_w3_handler1     3339865  17586580     False
# 431        NaN  main_w3_handler0     2789374  18017121     False
# 432        NaN  main_w3_handler0     3289187  17537395     False
# 433        NaN  main_w3_handler1     3289187  17537390     False
# 434        NaN  main_w3_handler1     3289187  17537410     False
# 435        NaN  main_w3_handler1     3347550  17658183     False
# 436        NaN  main_w4_handler0     3289187  17537423     False
# 437        NaN  main_w3_handler1     3289187  17537397     False
# 438        NaN  main_w4_handler0     3351824  17712625     False
# 439        NaN  main_w3_handler1     3289187  17537404     False
# 440        NaN  main_w4_handler1     3289187  17537393     False
# 441        NaN  main_w4_handler0     3351824  17742829     False
# 442        NaN  main_w3_handler0     3392975  18048766     False
# 443        NaN  main_w4_handler0     3289187  17537409     False
# 444        NaN  main_w3_handler0     3289187  17537413     False
# 445        NaN  main_w4_handler1     3289187  17537407     False
# 446        NaN  main_w3_handler0     3455176  18638334     False
# 447        NaN  main_w4_handler0     3389951  18130210     False
# 448        NaN  main_w3_handler1     3447840  18627910     False
# 449        NaN  main_w3_handler0     3411071  18205401     False
# 450        NaN  main_w4_handler1     3447840  18565039     False
# 451        NaN  main_w4_handler0     3310866  18539390     False
#
#                                                   info      ...       \
# 0    This job was terminated because it ran longer ...      ...
# 1    This job was terminated because it ran longer ...      ...
# 2    This job was terminated because it ran longer ...      ...
# 3    This job was terminated because it ran longer ...      ...
# 4    This job was terminated because it ran longer ...      ...
# 5    This job was terminated because it ran longer ...      ...
# 6    This job was terminated because it ran longer ...      ...
# 7    This job was terminated because it ran longer ...      ...
# 8    This job was terminated because it ran longer ...      ...
# 9    This job was terminated because it ran longer ...      ...
# 10   This job was terminated because it ran longer ...      ...
# 11   This job was terminated because it ran longer ...      ...
# 12   This job was terminated because it ran longer ...      ...
# 13   This job was terminated because it ran longer ...      ...
# 14   This job was terminated because it ran longer ...      ...
# 15   This job was terminated because it ran longer ...      ...
# 16   This job was terminated because it ran longer ...      ...
# 17   This job was terminated because it ran longer ...      ...
# 18   This job was terminated because it ran longer ...      ...
# 19   This job was terminated because it ran longer ...      ...
# 20   This job was terminated because it ran longer ...      ...
# 21   This job was terminated because it ran longer ...      ...
# 22   This job was terminated because it ran longer ...      ...
# 23   This job was terminated because it ran longer ...      ...
# 24   This job was terminated because it ran longer ...      ...
# 25   This job was terminated because it ran longer ...      ...
# 26   This job was terminated because it ran longer ...      ...
# 27   This job was terminated because it ran longer ...      ...
# 28   This job was terminated because it ran longer ...      ...
# 29   This job was terminated because it ran longer ...      ...
# ..                                                 ...      ...
# 422  This job was terminated because it ran longer ...      ...
# 423  This job was terminated because it ran longer ...      ...
# 424  This job was terminated because it ran longer ...      ...
# 425  This job was terminated because it ran longer ...      ...
# 426  This job was terminated because it ran longer ...      ...
# 427  This job was terminated because it ran longer ...      ...
# 428  This job was terminated because it ran longer ...      ...
# 429  This job was terminated because it ran longer ...      ...
# 430  This job was terminated because it ran longer ...      ...
# 431  This job was terminated because it ran longer ...      ...
# 432  This job was terminated because it ran longer ...      ...
# 433  This job was terminated because it ran longer ...      ...
# 434  This job was terminated because it ran longer ...      ...
# 435  This job was terminated because it ran longer ...      ...
# 436  This job was terminated because it ran longer ...      ...
# 437  This job was terminated because it ran longer ...      ...
# 438  This job was terminated because it ran longer ...      ...
# 439  This job was terminated because it ran longer ...      ...
# 440  This job was terminated because it ran longer ...      ...
# 441  This job was terminated because it ran longer ...      ...
# 442  This job was terminated because it ran longer ...      ...
# 443  This job was terminated because it ran longer ...      ...
# 444  This job was terminated because it ran longer ...      ...
# 445  This job was terminated because it ran longer ...      ...
# 446  This job was terminated because it ran longer ...      ...
# 447  This job was terminated because it ran longer ...      ...
# 448  This job was terminated because it ran longer ...      ...
# 449  This job was terminated because it ran longer ...      ...
# 450  This job was terminated because it ran longer ...      ...
# 451  This job was terminated because it ran longer ...      ...
#
#      parameters.range.seq_range_start runner_name  session_id  state  \
# 0                                 NaN         NaN  21802324.0  error
# 1                                 NaN         NaN  22868221.0  error
# 2                                 NaN         NaN  20525383.0  error
# 3                                 NaN         NaN  22131479.0  error
# 4                                 NaN         NaN  21715330.0  error
# 5                                 NaN         NaN  22209590.0  error
# 6                                 NaN         NaN  21856921.0  error
# 7                                 NaN         NaN  22909611.0  error
# 8                                 NaN         NaN  22482782.0  error
# 9                                 NaN         NaN  22171119.0  error
# 10                                NaN         NaN  27769576.0  error
# 11                                NaN         NaN  22276696.0  error
# 12                                NaN         NaN  22276696.0  error
# 13                                NaN         NaN  22276696.0  error
# 14                                NaN         NaN  22276696.0  error
# 15                                NaN         NaN  21588801.0  error
# 16                                NaN         NaN  22188170.0  error
# 17                                NaN         NaN  22774578.0  error
# 18                                NaN         NaN  22631479.0  error
# 19                                NaN         NaN  22887691.0  error
# 20                                NaN         NaN  23772515.0  error
# 21                                NaN         NaN  21897366.0  error
# 22                                NaN         NaN  22798094.0  error
# 23                                NaN         NaN  22887691.0  error
# 24                                NaN         NaN  23653527.0  error
# 25                                NaN         NaN  23272037.0  error
# 26                                NaN         NaN  23331618.0  error
# 27                                NaN         NaN  23269259.0  error
# 28                                NaN         NaN  23305720.0  error
# 29                                NaN         NaN  23328193.0  error
# ..                                ...         ...         ...    ...
# 422                               NaN         NaN  41984926.0  error
# 423                               NaN         NaN  41320208.0  error
# 424                               NaN         NaN  41807700.0  error
# 425                               NaN         NaN  41320208.0  error
# 426                               NaN         NaN  41984926.0  error
# 427                               NaN         NaN  41984926.0  error
# 428                               NaN         NaN  41320208.0  error
# 429                               NaN         NaN  41320208.0  error
# 430                               NaN         NaN  42258036.0  error
# 431                               NaN         NaN  43125889.0  error
# 432                               NaN         NaN  41320208.0  error
# 433                               NaN         NaN  41320208.0  error
# 434                               NaN         NaN  41320208.0  error
# 435                               NaN         NaN  42379700.0  error
# 436                               NaN         NaN  41320208.0  error
# 437                               NaN         NaN  41320208.0  error
# 438                               NaN         NaN  42487897.0  error
# 439                               NaN         NaN  41320208.0  error
# 440                               NaN         NaN  41320208.0  error
# 441                               NaN         NaN  42487897.0  error
# 442                               NaN         NaN  43217189.0  error
# 443                               NaN         NaN  41320208.0  error
# 444                               NaN         NaN  41320208.0  error
# 445                               NaN         NaN  41320208.0  error
# 446                               NaN         NaN  44418105.0  error
# 447                               NaN         NaN  43151935.0  error
# 448                               NaN         NaN  44036608.0  error
# 449                               NaN         NaN  42720343.0  error
# 450                               NaN         NaN  44036608.0  error
# 451                               1.0         NaN  44205974.0  error
#
#                                                tool_id tool_version  \
# 0    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 1    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 2    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 3    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 4    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 5    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 6    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 7    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 8    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 9    toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 10   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 11   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 12   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 13   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 14   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 15   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 16   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 17   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 18   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 19   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 20   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 21   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 22   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 23   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 24   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 25   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 26   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 27   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 28   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 29   toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# ..                                                 ...          ...
# 422  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 423  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 424  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 425  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 426  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 427  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 428  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 429  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 430  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 431  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 432  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 433  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 434  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 435  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 436  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 437  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 438  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 439  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 440  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 441  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 442  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 443  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 444  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 445  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 446  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 447  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 448  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 449  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 450  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
# 451  toolshed.g2.bx.psu.edu/repos/devteam/clustalw/...          0.1
#
#      traceback                 update_time   user_id       runtime
# 0          NaN  2015-03-16 03:42:43.844188   44130.0  1.296455e+05
# 1          NaN  2015-05-06 07:40:52.097159   61864.0  1.296525e+05
# 2          NaN  2015-03-22 04:33:36.575546       NaN  1.296402e+05
# 3          NaN  2015-04-01 15:28:00.685845       NaN  1.296483e+05
# 4          NaN  2015-04-01 23:00:02.254441   57139.0  1.296516e+05
# 5          NaN  2015-04-03 17:54:41.904714       NaN  1.312829e+05
# 6          NaN  2015-04-09 21:30:54.282705   60816.0  1.296499e+05
# 7          NaN  2015-05-08 02:39:54.624957       NaN  1.296479e+05
# 8          NaN  2015-04-16 19:32:00.929579       NaN  1.296608e+05
# 9          NaN  2015-04-19 00:57:20.142837   54480.0  1.296446e+05
# 10         NaN  2016-01-28 02:46:40.004605       NaN  1.296406e+05
# 11         NaN  2015-04-24 10:56:28.698424   62008.0  1.740301e+05
# 12         NaN  2015-04-23 23:12:26.041339   62008.0  1.318212e+05
# 13         NaN  2015-04-23 22:41:28.026353   62008.0  1.300772e+05
# 14         NaN  2015-04-24 17:59:34.552584   62008.0  1.993956e+05
# 15         NaN  2015-04-23 11:03:22.508852       NaN  1.296563e+05
# 16         NaN  2015-04-30 15:31:31.221564       NaN  1.296506e+05
# 17         NaN  2015-05-01 02:21:28.794535   32890.0  1.551762e+05
# 18         NaN  2015-05-04 14:29:16.937153   61604.0  1.296409e+05
# 19         NaN  2015-05-16 00:17:11.324906   40687.0  1.296597e+05
# 20         NaN  2015-06-25 00:59:06.686911       NaN  1.296761e+05
# 21         NaN  2015-04-30 15:31:59.139679   55300.0  1.296327e+05
# 22         NaN  2015-05-03 09:31:16.927386       NaN  2.630613e+05
# 23         NaN  2015-05-20 21:56:57.217511   40687.0  1.296386e+05
# 24         NaN  2015-06-25 16:34:57.733390   24157.0  1.296634e+05
# 25         NaN  2015-05-28 02:18:47.479103   50165.0  1.713726e+05
# 26         NaN  2015-05-30 22:58:48.606116   64216.0  1.296416e+05
# 27         NaN  2015-05-28 20:16:46.793734   56776.0  1.296321e+05
# 28         NaN  2015-05-29 10:37:48.045269       NaN  1.296336e+05
# 29         NaN  2015-05-31 04:36:19.775613   64235.0  1.296332e+05
# ..         ...                         ...       ...           ...
# 422        NaN  2017-11-23 03:01:14.647809  116109.0  1.296343e+05
# 423        NaN  2017-11-23 03:09:45.328511       NaN  1.296148e+05
# 424        NaN  2017-11-22 04:02:00.322006   51829.0  1.296235e+05
# 425        NaN  2017-11-23 03:10:15.559427       NaN  1.296443e+05
# 426        NaN  2017-11-23 03:01:14.717022  116109.0  1.296340e+05
# 427        NaN  2017-11-23 03:01:14.744512  116109.0  1.296334e+05
# 428        NaN  2017-11-24 15:10:30.440704       NaN  2.592500e+05
# 429        NaN  2017-11-24 15:10:30.668256       NaN  2.592590e+05
# 430        NaN  2017-11-27 14:59:33.201080       NaN  1.298991e+05
# 431        NaN  2018-01-14 03:08:05.486396   88365.0  1.296335e+05
# 432        NaN  2017-11-28 15:13:25.696880       NaN  6.050342e+05
# 433        NaN  2017-12-02 17:23:03.439223       NaN  9.584133e+05
# 434        NaN  2017-12-01 05:22:49.038229       NaN  8.287939e+05
# 435        NaN  2017-12-02 20:27:02.180500  117700.0  1.296284e+05
# 436        NaN  2017-12-06 05:35:56.642587       NaN  1.261578e+06
# 437        NaN  2017-12-04 17:35:43.001821       NaN  1.131971e+06
# 438        NaN  2017-12-07 15:17:41.679082  118069.0  1.296214e+05
# 439        NaN  2017-12-07 17:36:13.387309       NaN  1.391200e+06
# 440        NaN  2017-12-07 17:36:11.696854       NaN  1.391201e+06
# 441        NaN  2017-12-09 13:43:09.239486  118069.0  1.296374e+05
# 442        NaN  2018-01-18 01:49:11.798495  119975.0  1.296385e+05
# 443        NaN  2017-12-11 17:21:58.247272       NaN  1.735943e+06
# 444        NaN  2017-12-13 05:22:15.548509       NaN  1.865560e+06
# 445        NaN  2017-12-14 17:22:52.806620       NaN  1.995198e+06
# 446        NaN  2018-03-09 00:07:14.643648       NaN  1.296269e+05
# 447        NaN  2018-01-24 21:46:57.111605  119787.0  1.296215e+05
# 448        NaN  2018-03-08 06:42:25.960336   77009.0  1.296201e+05
# 449        NaN  2018-02-01 09:49:57.633477  112476.0  1.296869e+05
# 450        NaN  2018-03-03 05:39:40.137053   77009.0  1.437845e+05
# 451        NaN  2018-03-01 07:45:47.585623  115270.0  1.296649e+05
#
# [452 rows x 41 columns]

# %%
df
# Out:
#                   create_time destination_id     end_epoch  exit_code  \
# 0  2017-03-21 16:23:10.489046   slurm_normal  1.490114e+09          0
#
#       fasta fasta_filetype  galaxy_slots           handler  history_id  \
# 0  74366631          fasta           1.0  main_w3_handler1     3036274
#
#          id   ...    state  swaptotal template template_filetype  \
# 0  15356494   ...       ok  1023996.0        0             fasta
#
#                                              tool_id  tool_version traceback  \
# 0  toolshed.g2.bx.psu.edu/repos/jjohnson/mothur_t...        1.21.0       NaN
#
#                   update_time  user_id runtime
# 0  2017-03-21 16:26:44.419188      NaN    25.0
#
# [1 rows x 42 columns]

# %%
df["result"], df2["result"]="ok", "walltime error"

# %%
df.index=df["id"]
df2.index=df2["id"]

# %%
df=pd.concat([df,df2])

# %%
df=df.sort_values("id")

# %%
del df["id"]

# %%
df=df.reset_index()

# %%
del df["id"]

# %%
df=remove_bad_columns(df)
df=remove_bad_columns(df)

# %%
df_features, df_labels = df, df.pop("result")

# %%
from sklearn import dummy
chooser = ChooseFeatureColumns()
scaler = MyMapper()
regr=sklearn.ensemble.RandomForestClassifier(n_estimators=100, max_depth=2)
# regr=sklearn.dummy.DummyClassifier()
pipe = sklearn.pipeline.Pipeline([
    ('chooser',chooser),
    ('scaler', scaler),
])

# %%
test_size = 0.2
test_start=len(df_labels)-int(len(df_labels)*test_size)

split_randomly=False
time_split=True
if split_randomly and time_split:
    tr_features, ev_features, tr_labels, ev_labels = sklearn.model_selection.train_test_split(df_features, df_labels, test_size=test_size)
    print("splitting randomly")
elif time_split:
    tr_features, tr_labels, ev_features, ev_labels = df_features[:test_start], df_labels[:test_start], df_features[test_start:], df_labels[test_start:]
    print("splitting non-randomly")
if time_split and ((len(list(pipe.fit_transform(tr_features)))) != (len(list(pipe.transform(ev_features))))):
    print("!! pipe transformation broken")
    time_split=False
# Out:
# splitting non-randomly

# %%
df_features=pipe.fit_transform(df_features)
if time_split:
            tr_features=pipe.fit_transform(tr_features)
            ev_features=pipe.transform(ev_features)

# %%
regr.fit(tr_features,tr_labels)
ev_pred = regr.predict(ev_features)
accuracy=sklearn.metrics.accuracy_score(ev_labels,ev_pred) 
accuracy
# Out:
# 1.0

# %%
regr.fit(df_features, df_labels)
pred=regr.predict(df_features)
accuracy=sklearn.metrics.accuracy_score(df_labels,pred) 
accuracy
# Out:
# 1.0

# %%
ev_labels.unique()
# Out:
# array(['ok', 'walltime error'], dtype=object)

# %%
df_labels
# Out:
# 0                    ok
# 1                    ok
# 2                    ok
# 3                    ok
# 4        walltime error
# 5                    ok
# 6                    ok
# 7                    ok
# 8                    ok
# 9                    ok
# 10                   ok
# 11                   ok
# 12                   ok
# 13                   ok
# 14                   ok
# 15                   ok
# 16                   ok
# 17                   ok
# 18                   ok
# 19                   ok
# 20                   ok
# 21                   ok
# 22                   ok
# 23                   ok
# 24       walltime error
# 25                   ok
# 26                   ok
# 27                   ok
# 28                   ok
# 29                   ok
#               ...
# 10970                ok
# 10971                ok
# 10972                ok
# 10973                ok
# 10974                ok
# 10975                ok
# 10976                ok
# 10977                ok
# 10978    walltime error
# 10979                ok
# 10980                ok
# 10981                ok
# 10982                ok
# 10983                ok
# 10984                ok
# 10985                ok
# 10986                ok
# 10987                ok
# 10988                ok
# 10989                ok
# 10990    walltime error
# 10991                ok
# 10992                ok
# 10993                ok
# 10994                ok
# 10995                ok
# 10996    walltime error
# 10997                ok
# 10998                ok
# 10999                ok
# Name: result, Length: 11000, dtype: object

# %%
from matplotlib import pyplot as plt
plt.scatter(df_features["destination_id"], df_labels)

# %%
len(regr.feature_importances_)
# Out:
# 215

# %%
fi=dict(zip(list(df_features),regr.feature_importances_))

# %%
import operator
sorted(fi.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('galaxy_slots', 0.1471918510384688),
#  ('memtotal', 0.14174914289277737),
#  ('input', 0.09744328886502161),
#  ('processor_count', 0.08476891356893212),
#  ('parameters.outcontrol.out_seqnos_OFF', 0.064217789579252),
#  ('parameters.dbkey_"hg19"', 0.05701553312027118),
#  ('parameters.dnarna_"PROTEIN"', 0.04225767358280139),
#  ('parameters.dnarna_"DNA"', 0.0320544698190976),
#  ('parameters.outname_"Clustal_run"', 0.02999798692315255),
#  ('handler_main_w3_handler0', 0.023054944134113166),
#  ('parameters.outcontrol.outform_clustal', 0.0196723401113424),
#  ('parameters.outcontrol.__current_case__', 0.01710659511883538),
#  ('parameters.outcontrol.out_seqnos_nan', 0.013747889614329899),
#  ('handler_main_w1_handler0', 0.010873498430821558),
#  ('destination_id_rodeo_normal', 0.010791633911037322),
#  ('parameters.dbkey_"hg38"', 0.009736451119347346),
#  ('handler_main_w4_handler1', 0.008875953263021008),
#  ('handler_main_w2_handler1', 0.008700361060944439),
#  ('parameters.dbkey_"mycoTube_H37RV"', 0.008118003686832506),
#  ('parameters.dbkey_"10616"', 0.008101073240899237),
#  ('handler_main_w4_handler0', 0.007986350973049016),
#  ('parameters.outcontrol.outform_fasta', 0.007968483137225325),
#  ('parameters.dbkey_"28247"', 0.0071075132603742675),
#  ('destination_id_reserved', 0.00681350946037384),
#  ('parameters.dbkey_"dm3"', 0.006737540603779996),
#  ('parameters.range.mode_part', 0.006577143653220307),
#  ('parameters.outname_"Clustal_run TCss"', 0.006531086422328113),
#  ('parameters.dbkey_"?"', 0.006350407241132358),
#  ('parameters.outname_"Clustal_run_all"', 0.006166748717554313),
#  ('parameters.outname_"OTC Splice donor alignment"', 0.006071507931304597),
#  ('parameters.outname_"Cyanobacteria"', 0.0057333121928016964),
#  ('parameters.outname_"BarcodeA"', 0.0055981321320143045),
#  ('parameters.outcontrol.out_seqnos_ON', 0.005339451454128303),
#  ('parameters.outname_"MSA_baf3e2_unmapped"', 0.004442184318634043),
#  ('parameters.outname_"mysterious_clustalW_run"', 0.004266687807198304),
#  ('parameters.outname_"L1_Cf_CanFam3.1_CLUSTALW.fa"', 0.004013318534961362),
#  ('destination_id_roundup_single', 0.003987670374830112),
#  ('parameters.range.seq_range_end', 0.003969872185291704),
#  ('parameters.outname_"Shark alignment data"', 0.003928492068695403),
#  ('parameters.range.__current_case__', 0.0036171927514682158),
#  ('parameters.outname_"Clustal_run_BCG"', 0.0035969129207317147),
#  ('parameters.outname_"Clustal_run_16S_BLNAR"', 0.003559416731241125),
#  ('parameters.outname_"ag.aln"', 0.0034228563467796924),
#  ('parameters.outname_"Salma\'s align"', 0.0033556050482552563),
#  ('parameters.outcontrol.outform_phylip', 0.0032520284792168846),
#  ('parameters.outname_"ClustalW on data 15"', 0.0032175660362902853),
#  ('destination_id_slurm_normal', 0.0029367096254058083),
#  ('parameters.outname_"sept gene"', 0.0025840220709027794),
#  ('parameters.outname_"victor.phase2.contigs.022814.v03.aln02.ordered.plusHHV5ref.aln"',
#   0.0023855331623884868),
#  ('parameters.outname_"U Alignments"', 0.0023137392088465273),
#  ('parameters.dbkey_"mm10"', 0.0021372431291372235),
#  ('parameters.outname_"Clustal_run_Fasta2"', 0.0020688238453193787),
#  ('parameters.dbkey_"canFam3"', 0.001737781044124595),
#  ('parameters.outname_"Clustal_run2"', 0.001521815192758931),
#  ('parameters.outname_"Dun16_align"', 0.0014836070637660591),
#  ('parameters.outname_"completeregion.all.aligned.fasta"',
#   0.0014621157394895628),
#  ('parameters.out_order_"INPUT"', 0.0014376100031940114),
#  ('handler_main_w1_handler2', 0.0014186527532479612),
#  ('parameters.dbkey_"hg_g1k_v37"', 0.0010823649653478459),
#  ('parameters.outname_"Ypstb"', 0.0010156808113017397),
#  ('parameters.dbkey_"dm6"', 0.0008500680189276583),
#  ('parameters.outname_"genotype C ANDgenome2015.04.28"',
#   0.0008220355749362244),
#  ('parameters.dbkey_"danRer10"', 0.0007721065795228741),
#  ('parameters.outname_"Alignment Bi-Cel"', 0.00070677426520765),
#  ('parameters.outname_"Clustal_run S15 ACR3"', 0.000517767366736701),
#  ('parameters.range.seq_range_start', 0.0004348953006834537),
#  ('parameters.outname_"MATK British Isles Clustal"', 0.000388794676051245),
#  ('destination_id_slurm_single', 0.0003163117074294963),
#  ('chromInfo_filetype_len', 0.000110343380820746),
#  ('parameters.range.mode_complete', 6.050426320392571e-05),
#  ('parameters.dbkey_"strPur2"', 5.0945500797002894e-05),
#  ('parameters.dbkey_"16083"', 4.744277421308771e-05),
#  ('parameters.outname_"Clustal_run_Fasta3"', 4.5640259093175236e-05),
#  ('parameters.outname_"Run_2_alignment"', 4.5113053859691304e-05),
#  ('parameters.dbkey_"237"', 4.4099451482410674e-05),
#  ('parameters.outname_"hlanuc1"', 3.49573791780867e-05),
#  ('handler_main_w2_handler0', 3.1712079908604037e-05),
#  ('parameters.outname_"Clustal_ctn_run"', 3.0339791586984094e-05),
#  ('parameters.outname_"Nod2 Phylo"', 1.784428235505061e-05),
#  ('handler_main_w1_handler1', 2.2181459556199013e-07),
#  ('chromInfo', 0.0),
#  ('chromInfo_filetype_nan', 0.0),
#  ('handler_main_w3_handler1', 0.0),
#  ('input_filetype_fasta', 0.0),
#  ('input_filetype_tabular', 0.0),
#  ('job_runner_name', 0.0),
#  ('parameters.dbkey_"12"', 0.0),
#  ('parameters.dbkey_"190"', 0.0),
#  ('parameters.dbkey_"241"', 0.0),
#  ('parameters.dbkey_"278"', 0.0),
#  ('parameters.dbkey_"31"', 0.0),
#  ('parameters.dbkey_"81"', 0.0),
#  ('parameters.dbkey_"9618"', 0.0),
#  ('parameters.dbkey_"AgamP3__New"', 0.0),
#  ('parameters.dbkey_"Homo_sapiens_nuHg19_mtrCRS"', 0.0),
#  ('parameters.dbkey_"anoGam1"', 0.0),
#  ('parameters.dbkey_"baciSubt"', 0.0),
#  ('parameters.dbkey_"bradJapo"', 0.0),
#  ('parameters.dbkey_"hg18"', 0.0),
#  ('parameters.dbkey_"mm9"', 0.0),
#  ('parameters.dbkey_"rn5"', 0.0),
#  ('parameters.dbkey_"triCas2"', 0.0),
#  ('parameters.out_order_"ALIGNED"', 0.0),
#  ('parameters.outname_"3sp NAM domain with NAM-B"', 0.0),
#  ('parameters.outname_"A6_8_top200_clustal"', 0.0),
#  ('parameters.outname_"ASFV_various"', 0.0),
#  ('parameters.outname_"ASncmtRNA1 Al"', 0.0),
#  ('parameters.outname_"Alignment_nils"', 0.0),
#  ('parameters.outname_"All_A_Z_CONCATENATED_20170310Clustal_run"', 0.0),
#  ('parameters.outname_"Aln"', 0.0),
#  ('parameters.outname_"Bird target"', 0.0),
#  ('parameters.outname_"C1q_Rp_Seed_Nogap"', 0.0),
#  ('parameters.outname_"Clustal Alignment"', 0.0),
#  ('parameters.outname_"ClustalGuibourtia"', 0.0),
#  ('parameters.outname_"ClustalW 14 regions chrX control MCF7 Crawford"', 0.0),
#  ('parameters.outname_"ClustalW Alignment"', 0.0),
#  ('parameters.outname_"ClustalW_347g23"', 0.0),
#  ('parameters.outname_"ClustalW_FASTA"', 0.0),
#  ('parameters.outname_"ClustalW_alignment_HBV_ADBC"', 0.0),
#  ('parameters.outname_"ClustalW_of_collapsed_unaligned_reads"', 0.0),
#  ('parameters.outname_"Clustal_347g23"', 0.0),
#  ('parameters.outname_"Clustal_7loci"', 0.0),
#  ('parameters.outname_"Clustal_Cyano_CR"', 0.0),
#  ('parameters.outname_"Clustal_Test"', 0.0),
#  ('parameters.outname_"Clustal_Western_Zika"', 0.0),
#  ('parameters.outname_"Clustal_a22b25draft"', 0.0),
#  ('parameters.outname_"Clustal_alignment_HBV_A_D"', 0.0),
#  ('parameters.outname_"Clustal_benthamiana_lipase_cluster"', 0.0),
#  ('parameters.outname_"Clustal_chloro"', 0.0),
#  ('parameters.outname_"Clustal_fungi"', 0.0),
#  ('parameters.outname_"Clustal_hsp90a summits +/- 250bp"', 0.0),
#  ('parameters.outname_"Clustal_hsp90b summits +/- 250bp"', 0.0),
#  ('parameters.outname_"Clustal_mito"', 0.0),
#  ('parameters.outname_"Clustal_r"', 0.0),
#  ('parameters.outname_"Clustal_run S24 ZPR3"', 0.0),
#  ('parameters.outname_"Clustal_run catchP"', 0.0),
#  ('parameters.outname_"Clustal_run chp2"', 0.0),
#  ('parameters.outname_"Clustal_run chp4"', 0.0),
#  ('parameters.outname_"Clustal_run chp5"', 0.0),
#  ('parameters.outname_"Clustal_run+clones"', 0.0),
#  ('parameters.outname_"Clustal_run-10-OKT3-2nd"', 0.0),
#  ('parameters.outname_"Clustal_runHBV-C"', 0.0),
#  ('parameters.outname_"Clustal_run_1+3"', 0.0),
#  ('parameters.outname_"Clustal_run_14_7_15"', 0.0),
#  ('parameters.outname_"Clustal_run_32"', 0.0),
#  ('parameters.outname_"Clustal_run_61"', 0.0),
#  ('parameters.outname_"Clustal_run_A"', 0.0),
#  ('parameters.outname_"Clustal_run_Barx1"', 0.0),
#  ('parameters.outname_"Clustal_run_CDS_FASTA"', 0.0),
#  ('parameters.outname_"Clustal_run_Fasta10"', 0.0),
#  ('parameters.outname_"Clustal_run_Fasta4"', 0.0),
#  ('parameters.outname_"Clustal_run_Fasta5"', 0.0),
#  ('parameters.outname_"Clustal_run_Fasta6"', 0.0),
#  ('parameters.outname_"Clustal_run_Fasta7"', 0.0),
#  ('parameters.outname_"Clustal_run_Fasta8"', 0.0),
#  ('parameters.outname_"Clustal_run_GGH_Latinoamerica"', 0.0),
#  ('parameters.outname_"Clustal_run_LAMBDA"', 0.0),
#  ('parameters.outname_"Clustal_run_RLTR13D_halfnhalf"', 0.0),
#  ('parameters.outname_"Clustal_run_Sequence alignment XMPases to look at phosphorylation site SKSELEG"',
#   0.0),
#  ('parameters.outname_"Clustal_run_WP001 ClustalW"', 0.0),
#  ('parameters.outname_"Clustal_run_all genomes"', 0.0),
#  ('parameters.outname_"Clustal_run_practice_FlaviRefSeqs"', 0.0),
#  ('parameters.outname_"Clustal_run_test_1"', 0.0),
#  ('parameters.outname_"Clustal_runall_Mtb_genomes_aligned_Galaxy_Clustal"',
#   0.0),
#  ('parameters.outname_"Comparacion Xenopus laevis"', 0.0),
#  ('parameters.outname_"DUN16_align"', 0.0),
#  ('parameters.outname_"DmPGRP_alignment"', 0.0),
#  ('parameters.outname_"Dun16_aligned"', 0.0),
#  ('parameters.outname_"EB14_align"', 0.0),
#  ('parameters.outname_"Eb36_align"', 0.0),
#  ('parameters.outname_"Eb_align"', 0.0),
#  ('parameters.outname_"H3-Human-HA(20130101-20141231)"', 0.0),
#  ('parameters.outname_"H3-Human-HA(20140101-20141218)"', 0.0),
#  ('parameters.outname_"HA NR Complete Aligned"', 0.0),
#  ('parameters.outname_"HEV 1 4"', 0.0),
#  ('parameters.outname_"HLA-B_allign"', 0.0),
#  ('parameters.outname_"Madonna_trio_aligned"', 0.0),
#  ('parameters.outname_"PED"', 0.0),
#  ('parameters.outname_"PJ22 Gu ROI HW and N2"', 0.0),
#  ('parameters.outname_"Projet noro test1"', 0.0),
#  ('parameters.outname_"RBCL British Isles Clustal"', 0.0),
#  ('parameters.outname_"RLTR13D5_alignment_run"', 0.0),
#  ('parameters.outname_"Reg_Alignment_Test"', 0.0),
#  ('parameters.outname_"SDSE_Alignment"', 0.0),
#  ('parameters.outname_"TAREAN_AGLA_CL1_align"', 0.0),
#  ('parameters.outname_"V. parahaemolyticus"', 0.0),
#  ('parameters.outname_"VC_sequence_clustal"', 0.0),
#  ('parameters.outname_"WNV_AllUSA"', 0.0),
#  ('parameters.outname_"Zea-mays_clustalrun"', 0.0),
#  ('parameters.outname_"adent"', 0.0),
#  ('parameters.outname_"alignement_proteine_mads"', 0.0),
#  ('parameters.outname_"alignment_forward"', 0.0),
#  ('parameters.outname_"allineamento multiplo"', 0.0),
#  ('parameters.outname_"allseq_alignment"', 0.0),
#  ('parameters.outname_"arn16s.fasta"', 0.0),
#  ('parameters.outname_"cd4_rgh2ax"', 0.0),
#  ('parameters.outname_"cyanobacteria_All"', 0.0),
#  ('parameters.outname_"foot-and-mouth disease virus complete genome"', 0.0),
#  ('parameters.outname_"genotype E ANDgenome2015.04.28"', 0.0),
#  ('parameters.outname_"hlanuc2"', 0.0),
#  ('parameters.outname_"kdna_maln"', 0.0),
#  ('parameters.outname_"mce-galaxy"', 0.0),
#  ('parameters.outname_"ncbi_fncuc"', 0.0),
#  ('parameters.outname_"p_gingivalis_aligned"', 0.0),
#  ('parameters.outname_"phoA.aln"', 0.0),
#  ('parameters.outname_"ps"', 0.0),
#  ('parameters.outname_"ps_for_logo"', 0.0),
#  ('parameters.outname_"ps_phylip"', 0.0),
#  ('parameters.outname_"rdsrAB_1Feb_align"', 0.0),
#  ('parameters.outname_"rum450align"', 0.0),
#  ('parameters.outname_"s_mutans_aligned"', 0.0),
#  ('parameters.outname_"souches_Cote_Ivoire"', 0.0),
#  ('parameters.outname_"sus scofa do.aln"', 0.0),
#  ('parameters.outname_"t_forsythia_aligned"', 0.0),
#  ('parameters.outname_"treponemy_aligned"', 0.0)]
