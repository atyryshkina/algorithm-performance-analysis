# %%
import argparse
import scipy
from sklearn.externals import joblib
import math

import pandas as pd

from sklearn import preprocessing
from sklearn_pandas import gen_features
from sklearn_pandas import DataFrameMapper

from sklearn import ensemble
import sklearn
import numpy as np
from matplotlib import pyplot as plt
from preprocessing import ChooseFeatureColumns
from preprocessing import MyMapper
import ast
import os
import skgarden

import mysql.connector
from tabulate import tabulate

# %%
def remove_bad_columns(df):
        parameters = [i for i in list(df) if (i.startswith("parameters.") and not i.startswith("parameters.__job_r"))]
        filetypes=[i for i in list(df) if (i.endswith("_filetype") and not i.startswith("parameters.__job_r"))]
        files=[i[:-9] for i in filetypes]
        bad_parameters=["parameters.__workflow_invocation_uuid__","parameters.chromInfo"]
        for parameter in parameters:
            series=df[parameter].dropna()
            if all(type(item)==str and item.startswith('"') for item in series): 
                try:
                    df[parameter]=df[parameter].str[1:-1].astype(float)
                except:
                    pass
            if len(df[parameter].unique())>=0.5*df.shape[0]:
                bad_parameters.append(parameter)
            if df[parameter].dtype == object and len(df[parameter].unique())>=10*df.shape[1]:
                bad_parameters.append(parameter)
            if all(type(item)==str and item.startswith("[") and item.endswith("]") for item in series):#  and item.startswith("[{'src'")
                if all(type(ast.literal_eval(item))==list for item in series):
                    bad_parameters.append(parameter)
        for file in files:
            bad_parameters.append("parameters."+file)
            bad_parameters.append("parameters."+file+".values")
            bad_parameters.append("parameters."+file+"|__identifier__")
        for param in set(bad_parameters):
            try:
                parameters.remove(param)
            except:
                pass
        hardware=[
             'destination_id',
#          'galaxy_slots',
         'handler',
         'job_runner_name',
#          'memtotal',
         'processor_count',
         'result']
        keep=parameters+filetypes+files+hardware
        columns=list(df)
        for column in columns:
            if not column in keep:
                del df[column]
        return df

# %%
filename="devteam_clustalw_clustalw_0.1"
df=pd.read_csv("../data/csv_dump/%s.csv"%filename)
df2=pd.read_csv("walltime_csv/%s.csv"%filename)
df["result"], df2["result"]="ok", "walltime error"
df.index=df["id"]
df2.index=df2["id"]
df=pd.concat([df,df2])
df=df.sort_values("id")
del df["id"]
df=df.reset_index()
del df["id"]
df=remove_bad_columns(df)
df=remove_bad_columns(df)
# Out:
# /Users/atyrysh/development/ber1/.venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from sklearn import dummy
chooser = ChooseFeatureColumns()
scaler = MyMapper()
regr=sklearn.ensemble.RandomForestClassifier(n_estimators=100, max_depth=12)
# regr=sklearn.dummy.DummyClassifier()
pipe = sklearn.pipeline.Pipeline([
    ('chooser',chooser),
    ('scaler', scaler),
])

test_size = 0.2

# %%
def get_prediction_metrics(df, benchmarks):
    benches={}
    benches["samples"]=df.shape[0]
    benches["num_errors"]=df["result"].value_counts()["walltime error"]
    df2=df.copy()
    df_features, df_labels = df2, df2.pop("result")

    test_start=len(df_labels)-int(len(df_labels)*test_size)

    split_randomly=False
    time_split=True
    if split_randomly and time_split:
        tr_features, ev_features, tr_labels, ev_labels = sklearn.model_selection.train_test_split(df_features, df_labels, test_size=test_size)
#         print("splitting randomly")
    elif time_split:
        tr_features, tr_labels, ev_features, ev_labels = df_features[:test_start], df_labels[:test_start], df_features[test_start:], df_labels[test_start:]
#         print("splitting non-randomly")
    if time_split and ((len(list(pipe.fit_transform(tr_features)))) != (len(list(pipe.transform(ev_features))))):
#         print("!! pipe transformation broken")
        time_split=False
    df_features=pipe.fit_transform(df_features)
    if time_split:
            tr_features=pipe.fit_transform(tr_features)
            ev_features=pipe.transform(ev_features)
    regr.fit(tr_features,tr_labels)
    ev_pred = regr.predict(ev_features)
    accuracy=sklearn.metrics.accuracy_score(ev_labels,ev_pred) 
    benches["accuracy_time_split"]=accuracy
    regr.fit(df_features, df_labels)
    pred=regr.predict(df_features)
    accuracy=sklearn.metrics.accuracy_score(df_labels,pred) 
    benches["accuracy"]=accuracy
    benchmarks.append(benches)
    return benchmarks

# %%
benchmarks=[]
ar=np.arange(100,df.shape[0], 100)
for i in ar:
    print("%d/%d"%(i, ar[-1]))
    
    benchmarks=get_prediction_metrics(df.sample(i), benchmarks)
print("done")
# Out:
# 100/17600
# 200/17600
# 300/17600
# 400/17600
# 500/17600
# 600/17600
# 700/17600
# 800/17600
# 900/17600
# 1000/17600
# 1100/17600
# 1200/17600
# 1300/17600
# 1400/17600
# 1500/17600
# 1600/17600
# 1700/17600
# 1800/17600
# 1900/17600
# 2000/17600
# 2100/17600
# 2200/17600
# 2300/17600
# 2400/17600
# 2500/17600
# 2600/17600
# 2700/17600
# 2800/17600
# 2900/17600
# 3000/17600
# 3100/17600
# 3200/17600
# 3300/17600
# 3400/17600
# 3500/17600
# 3600/17600
# 3700/17600
# 3800/17600
# 3900/17600
# 4000/17600
# 4100/17600
# 4200/17600
# 4300/17600
# 4400/17600
# 4500/17600
# 4600/17600
# 4700/17600
# 4800/17600
# 4900/17600
# 5000/17600
# 5100/17600
# 5200/17600
# 5300/17600
# 5400/17600
# 5500/17600
# 5600/17600
# 5700/17600
# 5800/17600
# 5900/17600
# 6000/17600
# 6100/17600
# 6200/17600
# 6300/17600
# 6400/17600
# 6500/17600
# 6600/17600
# 6700/17600
# 6800/17600
# 6900/17600
# 7000/17600
# 7100/17600
# 7200/17600
# 7300/17600
# 7400/17600
# 7500/17600
# 7600/17600
# 7700/17600
# 7800/17600
# 7900/17600
# 8000/17600
# 8100/17600
# 8200/17600
# 8300/17600
# 8400/17600
# 8500/17600
# 8600/17600
# 8700/17600
# 8800/17600
# 8900/17600
# 9000/17600
# 9100/17600
# 9200/17600
# 9300/17600
# 9400/17600
# 9500/17600
# 9600/17600
# 9700/17600
# 9800/17600
# 9900/17600
# 10000/17600
# 10100/17600
# 10200/17600
# 10300/17600
# 10400/17600
# 10500/17600
# 10600/17600
# 10700/17600
# 10800/17600
# 10900/17600
# 11000/17600
# 11100/17600
# 11200/17600
# 11300/17600
# 11400/17600
# 11500/17600
# 11600/17600
# 11700/17600
# 11800/17600
# 11900/17600
# 12000/17600
# 12100/17600
# 12200/17600
# 12300/17600
# 12400/17600
# 12500/17600
# 12600/17600
# 12700/17600
# 12800/17600
# 12900/17600
# 13000/17600
# 13100/17600
# 13200/17600
# 13300/17600
# 13400/17600
# 13500/17600
# 13600/17600
# 13700/17600
# 13800/17600
# 13900/17600
# 14000/17600
# 14100/17600
# 14200/17600
# 14300/17600
# 14400/17600
# 14500/17600
# 14600/17600
# 14700/17600
# 14800/17600
# 14900/17600
# 15000/17600
# 15100/17600
# 15200/17600
# 15300/17600
# 15400/17600
# 15500/17600
# 15600/17600
# 15700/17600
# 15800/17600
# 15900/17600
# 16000/17600
# 16100/17600
# 16200/17600
# 16300/17600
# 16400/17600
# 16500/17600
# 16600/17600
# 16700/17600
# 16800/17600
# 16900/17600
# 17000/17600
# 17100/17600
# 17200/17600
# 17300/17600
# 17400/17600
# 17500/17600
# 17600/17600
# done

# %%
df2=pd.DataFrame(benchmarks)

# %%
from matplotlib import pyplot as plt
plt.scatter(df2["samples"], df2["accuracy"])

# %%
df2
# Out:
#      accuracy  accuracy_time_split  num_errors  samples
# 0         1.0                  1.0           5      100
# 1         1.0                  1.0           4      200
# 2         1.0                  1.0           8      300
# 3         1.0                  1.0           8      400
# 4         1.0                  1.0          16      500
# 5         1.0                  1.0          17      600
# 6         1.0                  1.0          16      700
# 7         1.0                  1.0          17      800
# 8         1.0                  1.0          21      900
# 9         1.0                  1.0          31     1000
# 10        1.0                  1.0          20     1100
# 11        1.0                  1.0          28     1200
# 12        1.0                  1.0          33     1300
# 13        1.0                  1.0          34     1400
# 14        1.0                  1.0          40     1500
# 15        1.0                  1.0          36     1600
# 16        1.0                  1.0          41     1700
# 17        1.0                  1.0          41     1800
# 18        1.0                  1.0          42     1900
# 19        1.0                  1.0          44     2000
# 20        1.0                  1.0          57     2100
# 21        1.0                  1.0          49     2200
# 22        1.0                  1.0          57     2300
# 23        1.0                  1.0          60     2400
# 24        1.0                  1.0          66     2500
# 25        1.0                  1.0          73     2600
# 26        1.0                  1.0          74     2700
# 27        1.0                  1.0          74     2800
# 28        1.0                  1.0          76     2900
# 29        1.0                  1.0          65     3000
# ..        ...                  ...         ...      ...
# 146       1.0                  1.0         374    14700
# 147       1.0                  1.0         386    14800
# 148       1.0                  1.0         380    14900
# 149       1.0                  1.0         383    15000
# 150       1.0                  1.0         387    15100
# 151       1.0                  1.0         400    15200
# 152       1.0                  1.0         399    15300
# 153       1.0                  1.0         392    15400
# 154       1.0                  1.0         403    15500
# 155       1.0                  1.0         390    15600
# 156       1.0                  1.0         399    15700
# 157       1.0                  1.0         398    15800
# 158       1.0                  1.0         410    15900
# 159       1.0                  1.0         420    16000
# 160       1.0                  1.0         416    16100
# 161       1.0                  1.0         420    16200
# 162       1.0                  1.0         410    16300
# 163       1.0                  1.0         410    16400
# 164       1.0                  1.0         417    16500
# 165       1.0                  1.0         431    16600
# 166       1.0                  1.0         435    16700
# 167       1.0                  1.0         434    16800
# 168       1.0                  1.0         439    16900
# 169       1.0                  1.0         441    17000
# 170       1.0                  1.0         436    17100
# 171       1.0                  1.0         441    17200
# 172       1.0                  1.0         441    17300
# 173       1.0                  1.0         448    17400
# 174       1.0                  1.0         449    17500
# 175       1.0                  1.0         451    17600
#
# [176 rows x 4 columns]

# %%
df
# Out:
#        chromInfo chromInfo_filetype  destination_id  galaxy_slots  \
# 0            NaN                NaN    slurm_single           NaN
# 1            NaN                NaN    slurm_single           NaN
# 2            NaN                NaN    slurm_single           NaN
# 3            NaN                NaN    slurm_single           NaN
# 4            NaN                NaN    slurm_single           NaN
# 5            NaN                NaN    slurm_single           NaN
# 6            NaN                NaN    slurm_single           NaN
# 7            NaN                NaN    slurm_single           NaN
# 8            NaN                NaN    slurm_single           NaN
# 9            NaN                NaN    slurm_single           NaN
# 10           NaN                NaN    slurm_single           NaN
# 11           NaN                NaN    slurm_single           NaN
# 12           NaN                NaN    slurm_single           NaN
# 13           NaN                NaN    slurm_single           NaN
# 14           NaN                NaN    slurm_single           NaN
# 15           NaN                NaN    slurm_single           NaN
# 16           NaN                NaN    slurm_single           NaN
# 17           NaN                NaN    slurm_single           NaN
# 18           NaN                NaN    slurm_single           NaN
# 19           NaN                NaN    slurm_single           NaN
# 20           NaN                NaN    slurm_single           NaN
# 21           NaN                NaN    slurm_single           NaN
# 22           NaN                NaN    slurm_single           NaN
# 23           NaN                NaN    slurm_single           NaN
# 24           NaN                NaN    slurm_single           NaN
# 25           NaN                NaN    slurm_single           NaN
# 26           NaN                NaN  roundup_single           1.0
# 27           NaN                NaN  roundup_single           1.0
# 28           NaN                NaN  roundup_single           1.0
# 29           NaN                NaN  roundup_single           1.0
# ...          ...                ...             ...           ...
# 17604        NaN                NaN    slurm_normal           1.0
# 17605        NaN                NaN    slurm_normal           1.0
# 17606        NaN                NaN    slurm_normal           1.0
# 17607        NaN                NaN    slurm_normal           1.0
# 17608        NaN                NaN    slurm_normal           1.0
# 17609        NaN                NaN    slurm_normal           1.0
# 17610        NaN                NaN    slurm_normal           1.0
# 17611        NaN                NaN    slurm_normal           1.0
# 17612        NaN                NaN    slurm_normal           1.0
# 17613        NaN                NaN    slurm_normal           1.0
# 17614        NaN                NaN    slurm_normal           1.0
# 17615        NaN                NaN    slurm_normal           1.0
# 17616        NaN                NaN    slurm_normal           1.0
# 17617        NaN                NaN    slurm_normal           1.0
# 17618        NaN                NaN    slurm_normal           1.0
# 17619        NaN                NaN    slurm_normal           1.0
# 17620        NaN                NaN    slurm_normal           1.0
# 17621        NaN                NaN    slurm_normal           1.0
# 17622        NaN                NaN    slurm_normal           1.0
# 17623        NaN                NaN    slurm_normal           1.0
# 17624        NaN                NaN    slurm_normal           1.0
# 17625        NaN                NaN    slurm_normal           1.0
# 17626        NaN                NaN    slurm_normal           1.0
# 17627        NaN                NaN    slurm_normal           1.0
# 17628        NaN                NaN    slurm_normal           1.0
# 17629        NaN                NaN    slurm_normal           1.0
# 17630        NaN                NaN    slurm_normal           1.0
# 17631        NaN                NaN    slurm_normal           1.0
# 17632        NaN                NaN    slurm_normal           1.0
# 17633        NaN                NaN    slurm_normal           1.0
#
#                 handler       input input_filetype job_runner_name  \
# 0      main_w1_handler1  1201020596          fasta           slurm
# 1      main_w2_handler1    21373765          fasta           slurm
# 2      main_w1_handler0    21373765          fasta           slurm
# 3      main_w2_handler1     8998242          fasta           slurm
# 4      main_w1_handler0    12083536          fasta           slurm
# 5      main_w1_handler1    12083536          fasta           slurm
# 6      main_w2_handler0   725845860          fasta           slurm
# 7      main_w2_handler0   725845860          fasta           slurm
# 8      main_w2_handler0     7313716          fasta           slurm
# 9      main_w1_handler1     8930356          fasta           slurm
# 10     main_w1_handler1     8413395          fasta           slurm
# 11     main_w2_handler0     8282989          fasta           slurm
# 12     main_w2_handler1    49017137          fasta           slurm
# 13     main_w1_handler0  1110736084          fasta           slurm
# 14     main_w2_handler1     9437195          fasta           slurm
# 15     main_w1_handler1     8204142          fasta           slurm
# 16     main_w2_handler1     9260894          fasta           slurm
# 17     main_w1_handler0     3967272          fasta           slurm
# 18     main_w1_handler1     7104172          fasta           slurm
# 19     main_w1_handler1     4529224          fasta           slurm
# 20     main_w2_handler0     8643709          fasta           slurm
# 21     main_w1_handler0    45384814          fasta           slurm
# 22     main_w1_handler0  1257894758          fasta           slurm
# 23     main_w2_handler1     3732697          fasta           slurm
# 24     main_w2_handler0    54023339          fasta           slurm
# 25     main_w2_handler0     4549824          fasta           slurm
# 26     main_w2_handler0    99573866          fasta           slurm
# 27     main_w1_handler1    99573866          fasta           slurm
# 28     main_w2_handler1        1673          fasta           slurm
# 29     main_w1_handler0    79601267          fasta           slurm
# ...                 ...         ...            ...             ...
# 17604  main_w3_handler0        2036          fasta           slurm
# 17605  main_w3_handler1        2036          fasta           slurm
# 17606  main_w4_handler1        1718          fasta           slurm
# 17607  main_w3_handler1        1213          fasta           slurm
# 17608  main_w3_handler1        2036          fasta           slurm
# 17609  main_w3_handler1        2036          fasta           slurm
# 17610  main_w3_handler0        1544          fasta           slurm
# 17611  main_w4_handler1        1408          fasta           slurm
# 17612  main_w4_handler0        2036          fasta           slurm
# 17613  main_w4_handler0        1218          fasta           slurm
# 17614  main_w3_handler0        2036          fasta           slurm
# 17615  main_w3_handler1        1218          fasta           slurm
# 17616  main_w3_handler1        2036          fasta           slurm
# 17617  main_w4_handler1        2036          fasta           slurm
# 17618  main_w3_handler1        1218          fasta           slurm
# 17619  main_w4_handler0        2036          fasta           slurm
# 17620  main_w3_handler1        1746          fasta           slurm
# 17621  main_w3_handler0        1806          fasta           slurm
# 17622  main_w3_handler0        1772          fasta           slurm
# 17623  main_w4_handler1        2010          fasta           slurm
# 17624  main_w3_handler1        1910          fasta           slurm
# 17625  main_w4_handler0        2026          fasta           slurm
# 17626  main_w4_handler0        1910          fasta           slurm
# 17627  main_w4_handler0        1899          fasta           slurm
# 17628  main_w4_handler0        1899          fasta           slurm
# 17629  main_w4_handler0        1871          fasta           slurm
# 17630  main_w3_handler1        4496          fasta           slurm
# 17631  main_w3_handler1        4496          fasta           slurm
# 17632  main_w3_handler1        4587          fasta           slurm
# 17633  main_w3_handler1      217267          fasta           slurm
#
#           memtotal              parameters.dbkey       ...        \
# 0              NaN                        "hg19"       ...
# 1              NaN                        "hg19"       ...
# 2              NaN                        "hg19"       ...
# 3              NaN                        "hg19"       ...
# 4              NaN                           "?"       ...
# 5              NaN                           "?"       ...
# 6              NaN                        "mm10"       ...
# 7              NaN                        "mm10"       ...
# 8              NaN                           "?"       ...
# 9              NaN              "mycoTube_H37RV"       ...
# 10             NaN                           "?"       ...
# 11             NaN                           "?"       ...
# 12             NaN                           "?"       ...
# 13             NaN                           "?"       ...
# 14             NaN                           "?"       ...
# 15             NaN                           "?"       ...
# 16             NaN                           "?"       ...
# 17             NaN                           "?"       ...
# 18             NaN                           "?"       ...
# 19             NaN                           "?"       ...
# 20             NaN                           "?"       ...
# 21             NaN                           "?"       ...
# 22             NaN  "Homo_sapiens_nuHg19_mtrCRS"       ...
# 23             NaN                        "hg19"       ...
# 24             NaN                         "mm9"       ...
# 25             NaN                           "?"       ...
# 26     132112264.0  "Homo_sapiens_nuHg19_mtrCRS"       ...
# 27     132112264.0  "Homo_sapiens_nuHg19_mtrCRS"       ...
# 28     132112264.0                           "?"       ...
# 29     132112264.0                        "hg19"       ...
# ...            ...                           ...       ...
# 17604  132112168.0                           "?"       ...
# 17605  132112168.0                           "?"       ...
# 17606  132112168.0                           "?"       ...
# 17607  132112168.0                           "?"       ...
# 17608  132112168.0                           "?"       ...
# 17609  132112168.0                           "?"       ...
# 17610  132112168.0                           "?"       ...
# 17611  132112168.0                           "?"       ...
# 17612  132112168.0                           "?"       ...
# 17613  132112168.0                           "?"       ...
# 17614  132112168.0                           "?"       ...
# 17615  132111800.0                           "?"       ...
# 17616  132111800.0                           "?"       ...
# 17617  132111800.0                           "?"       ...
# 17618  132111800.0                           "?"       ...
# 17619  132112168.0                           "?"       ...
# 17620  132111800.0                           "?"       ...
# 17621  132111800.0                           "?"       ...
# 17622  132112168.0                           "?"       ...
# 17623  132112168.0                           "?"       ...
# 17624  132111800.0                           "?"       ...
# 17625  132112168.0                           "?"       ...
# 17626  132112168.0                           "?"       ...
# 17627  132111800.0                           "?"       ...
# 17628  132112168.0                           "?"       ...
# 17629  132112168.0                           "?"       ...
# 17630  132112168.0                           "?"       ...
# 17631  132112168.0                           "?"       ...
# 17632  132112168.0                           "?"       ...
# 17633  132112168.0                           "?"       ...
#
#       parameters.out_order parameters.outcontrol.__current_case__  \
# 0                "ALIGNED"                                      0
# 1                "ALIGNED"                                      2
# 2                "ALIGNED"                                      2
# 3                "ALIGNED"                                      2
# 4                "ALIGNED"                                      0
# 5                "ALIGNED"                                      2
# 6                "ALIGNED"                                      2
# 7                "ALIGNED"                                      2
# 8                  "INPUT"                                      0
# 9                "ALIGNED"                                      2
# 10               "ALIGNED"                                      2
# 11               "ALIGNED"                                      0
# 12               "ALIGNED"                                      2
# 13               "ALIGNED"                                      2
# 14               "ALIGNED"                                      2
# 15               "ALIGNED"                                      2
# 16               "ALIGNED"                                      1
# 17               "ALIGNED"                                      2
# 18               "ALIGNED"                                      2
# 19               "ALIGNED"                                      2
# 20               "ALIGNED"                                      0
# 21               "ALIGNED"                                      2
# 22               "ALIGNED"                                      2
# 23               "ALIGNED"                                      2
# 24               "ALIGNED"                                      2
# 25               "ALIGNED"                                      2
# 26               "ALIGNED"                                      2
# 27               "ALIGNED"                                      2
# 28               "ALIGNED"                                      2
# 29               "ALIGNED"                                      2
# ...                    ...                                    ...
# 17604            "ALIGNED"                                      2
# 17605            "ALIGNED"                                      2
# 17606            "ALIGNED"                                      2
# 17607            "ALIGNED"                                      2
# 17608            "ALIGNED"                                      2
# 17609            "ALIGNED"                                      2
# 17610            "ALIGNED"                                      2
# 17611            "ALIGNED"                                      2
# 17612            "ALIGNED"                                      2
# 17613            "ALIGNED"                                      2
# 17614            "ALIGNED"                                      2
# 17615            "ALIGNED"                                      2
# 17616            "ALIGNED"                                      2
# 17617            "ALIGNED"                                      2
# 17618            "ALIGNED"                                      0
# 17619            "ALIGNED"                                      2
# 17620            "ALIGNED"                                      2
# 17621            "ALIGNED"                                      2
# 17622            "ALIGNED"                                      2
# 17623            "ALIGNED"                                      2
# 17624            "ALIGNED"                                      2
# 17625            "ALIGNED"                                      2
# 17626            "ALIGNED"                                      2
# 17627            "ALIGNED"                                      2
# 17628            "ALIGNED"                                      2
# 17629            "ALIGNED"                                      2
# 17630            "ALIGNED"                                      2
# 17631            "ALIGNED"                                      2
# 17632            "ALIGNED"                                      2
# 17633            "ALIGNED"                                      2
#
#        parameters.outcontrol.out_seqnos parameters.outcontrol.outform  \
# 0                                   NaN                         fasta
# 1                                   OFF                       clustal
# 2                                   OFF                       clustal
# 3                                   OFF                       clustal
# 4                                   NaN                         fasta
# 5                                   OFF                       clustal
# 6                                   OFF                       clustal
# 7                                   OFF                       clustal
# 8                                   NaN                         fasta
# 9                                   OFF                       clustal
# 10                                   ON                       clustal
# 11                                  NaN                         fasta
# 12                                  OFF                       clustal
# 13                                  OFF                       clustal
# 14                                  OFF                       clustal
# 15                                  OFF                       clustal
# 16                                  NaN                        phylip
# 17                                  OFF                       clustal
# 18                                  OFF                       clustal
# 19                                  OFF                       clustal
# 20                                  NaN                         fasta
# 21                                  OFF                       clustal
# 22                                  OFF                       clustal
# 23                                  OFF                       clustal
# 24                                  OFF                       clustal
# 25                                  OFF                       clustal
# 26                                  OFF                       clustal
# 27                                  OFF                       clustal
# 28                                  OFF                       clustal
# 29                                  OFF                       clustal
# ...                                 ...                           ...
# 17604                               OFF                       clustal
# 17605                               OFF                       clustal
# 17606                               OFF                       clustal
# 17607                               OFF                       clustal
# 17608                               OFF                       clustal
# 17609                               OFF                       clustal
# 17610                               OFF                       clustal
# 17611                               OFF                       clustal
# 17612                               OFF                       clustal
# 17613                               OFF                       clustal
# 17614                               OFF                       clustal
# 17615                               OFF                       clustal
# 17616                               OFF                       clustal
# 17617                               OFF                       clustal
# 17618                               NaN                         fasta
# 17619                               OFF                       clustal
# 17620                               OFF                       clustal
# 17621                               OFF                       clustal
# 17622                               OFF                       clustal
# 17623                               OFF                       clustal
# 17624                               OFF                       clustal
# 17625                               OFF                       clustal
# 17626                               OFF                       clustal
# 17627                               OFF                       clustal
# 17628                               OFF                       clustal
# 17629                               OFF                       clustal
# 17630                               OFF                       clustal
# 17631                               OFF                       clustal
# 17632                               OFF                       clustal
# 17633                               OFF                       clustal
#
#       parameters.range.__current_case__  parameters.range.mode  \
# 0                                     0               complete
# 1                                     0               complete
# 2                                     0               complete
# 3                                     0               complete
# 4                                     0               complete
# 5                                     0               complete
# 6                                     0               complete
# 7                                     0               complete
# 8                                     0               complete
# 9                                     0               complete
# 10                                    0               complete
# 11                                    0               complete
# 12                                    0               complete
# 13                                    0               complete
# 14                                    0               complete
# 15                                    0               complete
# 16                                    0               complete
# 17                                    0               complete
# 18                                    0               complete
# 19                                    0               complete
# 20                                    0               complete
# 21                                    0               complete
# 22                                    0               complete
# 23                                    0               complete
# 24                                    0               complete
# 25                                    0               complete
# 26                                    0               complete
# 27                                    0               complete
# 28                                    0               complete
# 29                                    0               complete
# ...                                 ...                    ...
# 17604                                 0               complete
# 17605                                 0               complete
# 17606                                 0               complete
# 17607                                 0               complete
# 17608                                 0               complete
# 17609                                 0               complete
# 17610                                 0               complete
# 17611                                 0               complete
# 17612                                 0               complete
# 17613                                 0               complete
# 17614                                 0               complete
# 17615                                 0               complete
# 17616                                 0               complete
# 17617                                 0               complete
# 17618                                 0               complete
# 17619                                 0               complete
# 17620                                 0               complete
# 17621                                 0               complete
# 17622                                 0               complete
# 17623                                 0               complete
# 17624                                 0               complete
# 17625                                 0               complete
# 17626                                 0               complete
# 17627                                 0               complete
# 17628                                 0               complete
# 17629                                 0               complete
# 17630                                 0               complete
# 17631                                 0               complete
# 17632                                 0               complete
# 17633                                 0               complete
#
#       parameters.range.seq_range_end  parameters.range.seq_range_start  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# 5                                NaN                               NaN
# 6                                NaN                               NaN
# 7                                NaN                               NaN
# 8                                NaN                               NaN
# 9                                NaN                               NaN
# 10                               NaN                               NaN
# 11                               NaN                               NaN
# 12                               NaN                               NaN
# 13                               NaN                               NaN
# 14                               NaN                               NaN
# 15                               NaN                               NaN
# 16                               NaN                               NaN
# 17                               NaN                               NaN
# 18                               NaN                               NaN
# 19                               NaN                               NaN
# 20                               NaN                               NaN
# 21                               NaN                               NaN
# 22                               NaN                               NaN
# 23                               NaN                               NaN
# 24                               NaN                               NaN
# 25                               NaN                               NaN
# 26                               NaN                               NaN
# 27                               NaN                               NaN
# 28                               NaN                               NaN
# 29                               NaN                               NaN
# ...                              ...                               ...
# 17604                            NaN                               NaN
# 17605                            NaN                               NaN
# 17606                            NaN                               NaN
# 17607                            NaN                               NaN
# 17608                            NaN                               NaN
# 17609                            NaN                               NaN
# 17610                            NaN                               NaN
# 17611                            NaN                               NaN
# 17612                            NaN                               NaN
# 17613                            NaN                               NaN
# 17614                            NaN                               NaN
# 17615                            NaN                               NaN
# 17616                            NaN                               NaN
# 17617                            NaN                               NaN
# 17618                            NaN                               NaN
# 17619                            NaN                               NaN
# 17620                            NaN                               NaN
# 17621                            NaN                               NaN
# 17622                            NaN                               NaN
# 17623                            NaN                               NaN
# 17624                            NaN                               NaN
# 17625                            NaN                               NaN
# 17626                            NaN                               NaN
# 17627                            NaN                               NaN
# 17628                            NaN                               NaN
# 17629                            NaN                               NaN
# 17630                            NaN                               NaN
# 17631                            NaN                               NaN
# 17632                            NaN                               NaN
# 17633                            NaN                               NaN
#
#        processor_count          result
# 0                  NaN  walltime error
# 1                  NaN  walltime error
# 2                  NaN  walltime error
# 3                  NaN  walltime error
# 4                  NaN  walltime error
# 5                  NaN  walltime error
# 6                  NaN  walltime error
# 7                  NaN  walltime error
# 8                  NaN  walltime error
# 9                  NaN  walltime error
# 10                 NaN  walltime error
# 11                 NaN  walltime error
# 12                 NaN  walltime error
# 13                 NaN  walltime error
# 14                 NaN  walltime error
# 15                 NaN  walltime error
# 16                 NaN  walltime error
# 17                 NaN  walltime error
# 18                 NaN  walltime error
# 19                 NaN  walltime error
# 20                 NaN  walltime error
# 21                 NaN  walltime error
# 22                 NaN  walltime error
# 23                 NaN  walltime error
# 24                 NaN  walltime error
# 25                 NaN  walltime error
# 26                32.0              ok
# 27                32.0              ok
# 28                32.0              ok
# 29                32.0              ok
# ...                ...             ...
# 17604             32.0              ok
# 17605             32.0              ok
# 17606             32.0              ok
# 17607             32.0              ok
# 17608             32.0              ok
# 17609             32.0              ok
# 17610             32.0              ok
# 17611             32.0              ok
# 17612             32.0              ok
# 17613             32.0              ok
# 17614             32.0              ok
# 17615             32.0              ok
# 17616             32.0              ok
# 17617             32.0              ok
# 17618             32.0              ok
# 17619             32.0              ok
# 17620             32.0              ok
# 17621             32.0              ok
# 17622             32.0              ok
# 17623             32.0              ok
# 17624             32.0              ok
# 17625             32.0              ok
# 17626             32.0              ok
# 17627             32.0              ok
# 17628             32.0              ok
# 17629             32.0              ok
# 17630             32.0              ok
# 17631             32.0              ok
# 17632             32.0              ok
# 17633             32.0              ok
#
# [17634 rows x 21 columns]

# %%
fi=dict(zip(list(df),regr.feature_importances_))

# %%
import operator
sorted(fi.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('galaxy_slots', 0.35016514796162307),
#  ('memtotal', 0.2994957303215902),
#  ('chromInfo_filetype', 0.2590154925302258),
#  ('destination_id', 0.06293474853458783),
#  ('parameters.range.__current_case__', 0.011261512078386904),
#  ('parameters.out_order', 0.0016858128205648958),
#  ('handler', 0.0008132821752379188),
#  ('input_filetype', 0.0005049139008728026),
#  ('parameters.outcontrol.outform', 0.00031883960881170994),
#  ('parameters.range.seq_range_end', 0.0002981768607065887),
#  ('result', 0.0002938721023288286),
#  ('parameters.outcontrol.__current_case__', 0.00023824886101700207),
#  ('parameters.range.mode', 0.00017571323924348042),
#  ('parameters.range.seq_range_start', 0.00014450203956096347),
#  ('job_runner_name', 0.000130738989797512),
#  ('processor_count', 0.00012426507375572733),
#  ('chromInfo', 8.332221077718885e-05),
#  ('parameters.outcontrol.out_seqnos', 8.273741062203537e-05),
#  ('parameters.dbkey', 5.679360553956279e-05),
#  ('parameters.dnarna', 5.6250178562091984e-05),
#  ('input', 5.014289560137658e-05)]
